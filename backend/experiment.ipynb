# %%
MRBEAST_ID = "UCJ0uqCI0Vqr2Rrt1HseGirg"

# %%
from googleapiclient.discovery import build
from youtube_transcript_api import YouTubeTranscriptApi, TranscriptsDisabled, VideoUnavailable
from dotenv import load_dotenv
import os
import random

def fetch_video_ids(channel_id: str) -> list[str]:
    """
    Fetches all video IDs from a YouTube channel.

    Args:
        channel_id (str): The YouTube channel ID.

    Returns:
        list: A list of video IDs from the channel.
    """
    load_dotenv()
    api_key = os.getenv("API_KEY")
    if not api_key:
        raise ValueError("API key not found. Ensure it is set in the .env file.")

    video_ids = []
    next_page_token = None

    with build("youtube", "v3", developerKey=api_key) as youtube:
        while True:
            request = youtube.search().list(
                part="id",
                channelId=channel_id,
                maxResults=50,
                pageToken=next_page_token,
                type="video"
            )
            response = request.execute()
            video_ids.extend(item["id"]["videoId"] for item in response.get("items", []))
            next_page_token = response.get("nextPageToken")

            if not next_page_token:
                break

    print('(fetch_video_ids) Video ids retrieved:', len(video_ids))
    return video_ids

def fetch_random_video_transcripts(channel_id: str, sample_size: int=5) -> list:
    """
    Retrieves transcripts from a random sample of videos from a YouTube channel.

    Args:
        channel_id (str): The YouTube channel ID.
        sample_size (int): Number of random videos to retrieve transcripts from.

    Returns:
        list: A list of transcripts (or a message if transcripts are not available).

    Example Return Value:
        [
            [  # Transcript of video 1
                {"text": "Hello world!", "start": 0.0, "duration": 1.5},
                {"text": "Welcome to the channel.", "start": 1.5, "duration": 2.0},
                ...
            ],
            [  # Transcript of video 2
                {"text": "This is another video.", "start": 0.0, "duration": 1.2},
                {"text": "Stay tuned for more content.", "start": 1.2, "duration": 2.3},
                ...
            ],
            "Transcript not available.",  # Video 3 has no transcript
            ...
        ]
    """
    video_ids = fetch_video_ids(channel_id)
    if not video_ids:
        raise ValueError("No videos found for the given channel ID.")

    sample_video_ids = random.sample(video_ids, min(sample_size, len(video_ids)))
    transcripts = []

    for video_id in sample_video_ids:
        try:
            transcript = YouTubeTranscriptApi.get_transcript(video_id)
            transcripts.append(transcript)  # Add the transcript directly
        except (TranscriptsDisabled, VideoUnavailable):
            transcripts.append("Transcript not available.")

    print('(fetch_random_video_transcripts) Transcripts retrieved:', len(transcripts))
    return transcripts

fetch_random_video_transcripts(MRBEAST_ID)
# Out:
# (fetch_video_ids) Video ids retrieved: 501
# (fetch_random_video_transcripts) Transcripts retrieved: 5
# [[{'text': '>> James: NOW DEMI YOU\nRECENTLY POSESSED A VIDEO.',
#    'start': 1.034,
#    'duration': 3.036},
#   {'text': '>> YEAH.', 'start': 4.07, 'duration': 0.234},
#   {'text': '>> James: SHOWING YOU TAKING\nDOWN YOUR BOYFRIEND WHO I THINK',
#    'start': 4.304,
#    'duration': 6.339},
#   {'text': 'IS AN MMA FIGHTER IN A FIGHT.',
#    'start': 10.643,
#    'duration': 1.836},
#   {'text': 'THIS IS THE VIDEO YOU POSTED THE\nOTHER DAY.',
#    'start': 12.479,
#    'duration': 8.174},
#   {'text': ">> THAT'S GOOD.", 'start': 20.653, 'duration': 1.202},
#   {'text': 'NICE TRANSITION.', 'start': 21.855, 'duration': 6.373},
#   {'text': '(CHEERS AND APPLAUSE)\nYZ NOW WHAT IS IS THAT MOVE',
#    'start': 28.228,
#    'duration': 4.137},
#   {'text': 'CALLED.', 'start': 32.365, 'duration': 0.434},
#   {'text': '>> SO THAT WAS-- WE WERE DOING\nJIU-JITSU, THAT WAS A DOUBLE',
#    'start': 32.799,
#    'duration': 5.105},
#   {'text': 'TAKE DOWN AND I WENT INTO AN ARM\nBAR.',
#    'start': 37.904,
#    'duration': 2.302},
#   {'text': '>> James: WHEN YOU WERE\nWATCHING THAT, YOU SAID GOOD,',
#    'start': 40.206,
#    'duration': 2.536},
#   {'text': 'VERY GOOD, GOOD TRANSITION.', 'start': 42.742, 'duration': 1.568},
#   {'text': 'YOU DO A BIT OF THIS STUFF AS\nWELL, RIGHT?',
#    'start': 44.31,
#    'duration': 2.403},
#   {'text': '>> I DO, YES.', 'start': 46.713, 'duration': 1.168},
#   {'text': 'I DID A FILM WITH GUY RITCHIE\nWHO IS A BLACK BELT WHERE',
#    'start': 47.881,
#    'duration': 9.843},
#   {'text': 'JIU-JITSU AND I IS A LITTLE OF\nIT WITH GUY RICHIE.',
#    'start': 57.724,
#    'duration': 3.937},
#   {'text': '>> James: THAT IS HOW YOU GOT\nINTO IT IT, JUST FROM HIM.',
#    'start': 61.661,
#    'duration': 2.836},
#   {'text': '>> YEAH, HE LIKES TO STAY ACTIVE\nIN CERTAIN THINGS, KEEP IT FUN,.',
#    'start': 64.497,
#    'duration': 4.905},
#   {'text': '>> James: EVERY NOW AND THEN,\nKICK SOMEONE IN THE FACE.',
#    'start': 69.402,
#    'duration': 2.136},
#   {'text': '>> WE COULD HAVE OURSELVES A\nLITTLE ROLL AROUND.',
#    'start': 71.538,
#    'duration': 2.035},
#   {'text': ">> James: YOU DO SOME ODD\nFIGHTING AS WELL, DON'T YOU?",
#    'start': 73.573,
#    'duration': 6.206},
#   {'text': '>> RUPERT WHAT ARE YOU INTO.', 'start': 79.779, 'duration': 1.702},
#   {'text': '>> I LOVER A ROLL AROUND, THAT\nIS WHAT I LOVE.',
#    'start': 81.481,
#    'duration': 2.402},
#   {'text': '>> I LOVE A ROLL AROUND WITH GUY\nRICHIE.',
#    'start': 83.883,
#    'duration': 2.269},
#   {'text': '>> HE HAS NEVER ASKED ME.', 'start': 86.152, 'duration': 4.538},
#   {'text': 'KRAVMAGA-W.', 'start': 90.69, 'duration': 0.3},
#   {'text': '>> James: WHAT IS THAT?', 'start': 90.99, 'duration': 1.535},
#   {'text': '>> THE ISRAELI SPECIAL FORCES\nOPEN HAND COMBAT.',
#    'start': 92.525,
#    'duration': 5.306},
#   {'text': "IT'S VERY-- IT'S REALLY NASTY.",
#    'start': 97.831,
#    'duration': 3.603},
#   {'text': ">> James: YEAH, I'M INTO THAT\nA BIT MYSELF.",
#    'start': 101.434,
#    'duration': 7.107},
#   {'text': '>> YEAH.', 'start': 108.541, 'duration': 2.536},
#   {'text': 'WHOA.', 'start': 111.077, 'duration': 0.2},
#   {'text': ">> James: YEAH, YOU DIDN'T\nEVEN SEE THAT.",
#    'start': 111.277,
#    'duration': 1.268},
#   {'text': '>> I DID SEE THAT.', 'start': 112.545, 'duration': 0.534},
#   {'text': ">> James: YOU DIDN'T.", 'start': 113.079, 'duration': 1.101},
#   {'text': '>> I DID.', 'start': 114.18, 'duration': 0.768},
#   {'text': 'I GOT YOUR ARM.', 'start': 114.948, 'duration': 5.739},
#   {'text': ">> James: YOU COULDN'T EVEN.",
#    'start': 120.687,
#    'duration': 0.567},
#   {'text': '>> NOT IN THIS OUTFIT.', 'start': 121.254, 'duration': 0.467},
#   {'text': '>> James: THERE YOU GO.', 'start': 121.721, 'duration': 0.801},
#   {'text': "DON'T YOU START.", 'start': 122.522, 'duration': 1.001}],
#  [{'text': 'CONGRATULATIONS ON THE FILM.', 'start': 0.367, 'duration': 3.803},
#   {'text': 'SUCH A TALENTED GROUP OF WOMEN.',
#    'start': 4.17,
#    'duration': 1.101},
#   {'text': 'THE MOST AMAZING CAST.', 'start': 5.271, 'duration': 1.469},
#   {'text': "THE QUESTION ON EVERYBODY'S LIPS\nIS WHO WAS YOUR FAVORITE MALE",
#    'start': 6.74,
#    'duration': 6.64},
#   {'text': 'CO-STAR IN THE MOVIE?', 'start': 13.38, 'duration': 1.334},
#   {'text': ">> WE DIDN'T REALLY HAVE ANY?",
#    'start': 14.714,
#    'duration': 3.337},
#   {'text': '>> HE WAS AMAZING.', 'start': 18.051, 'duration': 2.102},
#   {'text': '>> I LOVED HIM.', 'start': 20.153, 'duration': 0.5},
#   {'text': '>> A GUY THAT PLAYED THE GUARD\nAT THE CARTIER.',
#    'start': 20.653,
#    'duration': 3.003},
#   {'text': '>> HE WAS A-LIST.', 'start': 23.656, 'duration': 0.835},
#   {'text': '>> HE WAS AMAZING.', 'start': 24.491, 'duration': 1.067},
#   {'text': '>> AND VERY HANDSOME.', 'start': 25.558, 'duration': 1.402},
#   {'text': 'VERY HANDSOME.', 'start': 26.96, 'duration': 0.333},
#   {'text': ">> THE TWO GUYS THAT FOLLOWED\nANNIE'S CHARACTER, THE TWO",
#    'start': 27.293,
#    'duration': 3.971},
#   {'text': 'GUARDS, THEY WERE AMAZING.', 'start': 31.264, 'duration': 3.003},
#   {'text': '>> YES.', 'start': 34.267, 'duration': 1.835},
#   {'text': '>> OTHER THAN THAT, THERE WERE\nNO MEN CHARACTERS OF ANY KIND.',
#    'start': 36.102,
#    'duration': 3.003},
#   {'text': '>> AND THEN BEN.', 'start': 39.105, 'duration': 2.202},
#   {'text': '>> HE WAS IN THE ORIGINAL.', 'start': 41.307, 'duration': 1.936},
#   {'text': '>> WE RESURRECTED HIM.', 'start': 43.243, 'duration': 2.102},
#   {'text': ">> YOU SHOULD HAVE BEEN --\n>> YEAH, HE WASN'T DEAD.",
#    'start': 45.345,
#    'duration': 2.602},
#   {'text': ">> WHAT'S THE MATTER WITH YOU?",
#    'start': 47.947,
#    'duration': 1.202},
#   {'text': "WHAT'S THE MATTER?", 'start': 49.149, 'duration': 0.901},
#   {'text': 'ARE YOU UPSET?', 'start': 50.05, 'duration': 5.205},
#   {'text': 'OH.', 'start': 55.255, 'duration': 5.372},
#   {'text': 'WE HARDLY REMEMBER YOU.', 'start': 60.627, 'duration': 3.17},
#   {'text': 'JAMES.', 'start': 63.797, 'duration': 4.204},
#   {'text': 'JAMES UM, EACH CHARACTER AS\nTHEIR OWN SPECIAL SKILLS.',
#    'start': 68.001,
#    'duration': 3.804},
#   {'text': "WHAT'S EVERYBODY'S SPECIALTY?",
#    'start': 71.805,
#    'duration': 1.768},
#   {'text': '>> I WOULD SAY MINE IS JUST\nGENETIC THIEVERY.',
#    'start': 73.573,
#    'duration': 5.372},
#   {'text': "IT'S IN THE FAMILY.", 'start': 78.945, 'duration': 2.269},
#   {'text': "I'M DANNY OCEAN'S SISTER.", 'start': 81.214, 'duration': 2.236},
#   {'text': 'DANNY OCEAN IS PLAYED BY GEORGE\nCLOONEY.',
#    'start': 83.45,
#    'duration': 4.938},
#   {'text': '>> JORGE CLOONE.', 'start': 88.388, 'duration': 1.101},
#   {'text': '>> SHE SAID IT MAKES MY FACE\nLOOK UGLY.',
#    'start': 89.489,
#    'duration': 2.302},
#   {'text': '>> WHO SAID THAT?', 'start': 91.791, 'duration': 1.168},
#   {'text': '>> OH YEAH, MY FACE.', 'start': 92.959, 'duration': 2.703},
#   {'text': ">> BECAUSE YOU'RE LIKE JORGE\nCLOONE.",
#    'start': 95.662,
#    'duration': 3.503},
#   {'text': '>> James: HOW DO YOU GO ABOUT\nCALLING HIM JORGE CLOONE?',
#    'start': 99.165,
#    'duration': 5.005},
#   {'text': '>> BECAUSE I THOUGHT IT LOOKED\nGOOD DOING IT.',
#    'start': 104.17,
#    'duration': 2.336},
#   {'text': '>> James: JORGE CLOONE.', 'start': 106.506, 'duration': 3.07},
#   {'text': 'BUT NOW WHAT?', 'start': 109.576, 'duration': 0.567},
#   {'text': 'LOOK AT THIS ONE.', 'start': 110.143, 'duration': 1.068},
#   {'text': 'THIS ONE --\n>> GO AHEAD.', 'start': 111.211, 'duration': 3.236},
#   {'text': '>> NO, NOW EVERYONE IS FOCUSING\nON MY MOUTH.',
#    'start': 114.447,
#    'duration': 2.736},
#   {'text': 'NO.', 'start': 117.183, 'duration': 0.167},
#   {'text': 'NO.', 'start': 117.35, 'duration': 0.167},
#   {'text': 'NO.', 'start': 117.517, 'duration': 0.167},
#   {'text': 'NO.', 'start': 117.684, 'duration': 0.333},
#   {'text': 'NO.', 'start': 118.017, 'duration': 0.234},
#   {'text': '>> James: NO, NO.', 'start': 118.251, 'duration': 1.969},
#   {'text': 'YOU GOT THIS.', 'start': 120.22, 'duration': 0.567},
#   {'text': 'LOOK AWAY.', 'start': 120.787, 'duration': 0.867},
#   {'text': 'EVERYONE LOOK AWAY.', 'start': 121.654, 'duration': 1.635},
#   {'text': 'EVERYONE LOOK AWAY LOOK AWAY.',
#    'start': 123.289,
#    'duration': 0.601},
#   {'text': ">> PRETEND I'M IN THE BEDROOM\nALL BY MYSELF.",
#    'start': 123.89,
#    'duration': 3.203},
#   {'text': '>> James: LOOK AWAY.', 'start': 127.093, 'duration': 1.535},
#   {'text': 'LOOK BACK NOW.', 'start': 128.628, 'duration': 2.469},
#   {'text': '>> JORGE CLOONE.', 'start': 131.097, 'duration': 1.702},
#   {'text': '>> James: SO YOURS IS JUST\nTHIEVERY.',
#    'start': 132.799,
#    'duration': 4.538},
#   {'text': 'GENETIC THIEVERY.', 'start': 137.337, 'duration': 0.667},
#   {'text': ">> I'M THE FENCE, I'M THE SORT\nOF GO-BETWEEN, BETWEEN THE BUYER",
#    'start': 138.004,
#    'duration': 3.337},
#   {'text': 'AND SELLER.', 'start': 141.341, 'duration': 0.3},
#   {'text': '>> James: UH-HUH.', 'start': 141.641, 'duration': 1.935},
#   {'text': '>> YEAH, THANKS FOR THAT.', 'start': 143.576, 'duration': 1.702},
#   {'text': '>> James: AWKWAFINA, YOU ARE?',
#    'start': 145.278,
#    'duration': 2.069},
#   {'text': ">> I'M A LOW-LAND PICK POCKET.",
#    'start': 147.347,
#    'duration': 2.068},
#   {'text': ">> James: THAT'S RIGHT.", 'start': 149.415, 'duration': 1.035},
#   {'text': '>> THANK YOU.', 'start': 150.45, 'duration': 0.4},
#   {'text': 'THANK YOU.', 'start': 150.85, 'duration': 0.634},
#   {'text': '>> James: YOU ALL PLAY THIEVES\n, ALL RIGHT?',
#    'start': 151.484,
#    'duration': 2.936},
#   {'text': 'BUT NOT ONCE, OK, ONE OF YOU IS\nA GENUINE THIEF.',
#    'start': 154.42,
#    'duration': 7.475},
#   {'text': '>> I DID IT ONCE.', 'start': 161.895, 'duration': 1.635},
#   {'text': '>> James: TELL US.', 'start': 163.53, 'duration': 2.202},
#   {'text': '>> I WAS TOO OLD TO HAVE DONE IT\nTO HAVE IT NOT BE.',
#    'start': 165.732,
#    'duration': 2.369},
#   {'text': ">> James: WHAT'D YOU STEAL?", 'start': 168.101, 'duration': 2.469},
#   {'text': '>> I STOLE A VELVET BODY SUIT\nFROM A HIGH-END CLOTHING STORE',
#    'start': 170.57,
#    'duration': 3.337},
#   {'text': "ON COLUMBUS AVENUE, BUT IT WAS\n-- IT WAS -- SHE'S NOT GOING TO",
#    'start': 173.907,
#    'duration': 5.839},
#   {'text': 'BE MY FRIEND ANYONE -- ANYMORE.',
#    'start': 179.746,
#    'duration': 1.868},
#   {'text': 'IT WAS LIKE YESTERDAY.', 'start': 181.614, 'duration': 2.169},
#   {'text': 'NO, I JUST HAD A LOT OF VERY\nPOPULAR FRIENDS.',
#    'start': 183.783,
#    'duration': 2.469},
#   {'text': 'I FELT LIKE A BIG NUBE AND\nTHOUGHT I HAD TO DO IT TO BE',
#    'start': 186.252,
#    'duration': 4.071},
#   {'text': 'COOL.', 'start': 190.323, 'duration': 0.801},
#   {'text': 'I REGRET IT TO THIS DAY.', 'start': 191.124, 'duration': 1.234},
#   {'text': '>> James: WELL, WE TRACKED\nDOWN THE OWNER OF THAT STORE AND',
#    'start': 192.358,
#    'duration': 4.672},
#   {'text': "-- NO, I'M KIDDING.", 'start': 197.03, 'duration': 2.536},
#   {'text': 'HA-HA.', 'start': 199.566, 'duration': 5.905},
#   {'text': 'SANDRA, AWKWAFINA, DO YOU\nCONSIDER IT THIEVERY IF YOU TAKE',
#    'start': 205.471,
#    'duration': 2.67},
#   {'text': 'THINGS FROM A HOTEL?', 'start': 208.141, 'duration': 1.068},
#   {'text': '>> NO.', 'start': 209.209, 'duration': 0.2},
#   {'text': '>> WELL, NO.', 'start': 209.409, 'duration': 1.668},
#   {'text': 'HOLD ON.', 'start': 211.077, 'duration': 0.767},
#   {'text': 'HOLD ON.', 'start': 211.844, 'duration': 1.035},
#   {'text': 'HOLD ON.', 'start': 212.879, 'duration': 4.071},
#   {'text': "IT'S NOT A FINE LINE.", 'start': 216.95, 'duration': 1.067},
#   {'text': "IT'S A BIG LINE.", 'start': 218.017, 'duration': 1.001},
#   {'text': "IT'S NOT STEALING.", 'start': 219.018, 'duration': 1.068},
#   {'text': 'MY GRANDMA CALLED IT SHOPPING.',
#    'start': 220.086,
#    'duration': 1.602},
#   {'text': '>> James: OH REALLY?', 'start': 221.688, 'duration': 1.935},
#   {'text': '>> THE MICROWAVE?', 'start': 223.623, 'duration': 1.068},
#   {'text': 'WE TOOK THE HDMI CABLES OUT OF\nTHE DVD MACHINES.',
#    'start': 224.691,
#    'duration': 4.738},
#   {'text': '>> James: NO.', 'start': 229.429, 'duration': 1.501},
#   {'text': 'NO.', 'start': 230.93, 'duration': 0.167},
#   {'text': 'THAT IS THEFT.', 'start': 231.097, 'duration': 0.767},
#   {'text': 'WHAT DO YOU TAKE FROM HOTELS?',
#    'start': 231.864,
#    'duration': 1.502},
#   {'text': ">> I FEEL LIKE IT'S NOT\nNAIL-BOUND.",
#    'start': 233.366,
#    'duration': 2.436},
#   {'text': "IF IT'S NOT -- IF IT'S NOT\nNAILED DOWN, IT'S MEANT TO BE",
#    'start': 235.802,
#    'duration': 4.604},
#   {'text': 'ADVERTISEMENT FOR THE HOTEL.',
#    'start': 240.406,
#    'duration': 1.101},
#   {'text': '>> James: OH REALLY?', 'start': 241.507, 'duration': 1.502},
#   {'text': 'SO WOULD YOU TAKE A TOWEL?', 'start': 243.009, 'duration': 1.034},
#   {'text': 'WOULD YOU TAKE A TOWEL?', 'start': 244.043, 'duration': 1.202},
#   {'text': '>> YES.', 'start': 245.245, 'duration': 0.4},
#   {'text': 'I WOULD TAKE A TOWEL.', 'start': 245.645, 'duration': 0.867},
#   {'text': '>> James: NO!', 'start': 246.512, 'duration': 1.268},
#   {'text': ">> I'M OBVIOUSLY A THIEF SO --\nHA-HA.",
#    'start': 247.78,
#    'duration': 3.07},
#   {'text': '>> James: YOU WOULD TAKE A\nTOWEL.',
#    'start': 250.85,
#    'duration': 2.236},
#   {'text': 'WOULD YOU TAKE --\n>> I WOULD FEEL WEIRD TAKING THE',
#    'start': 253.086,
#    'duration': 2.502},
#   {'text': 'NICE HANGERS.', 'start': 255.588, 'duration': 1.902},
#   {'text': 'ALWAYS SEEMS CREEPY TO DO THAT.',
#    'start': 257.49,
#    'duration': 0.634},
#   {'text': '>> James: WHAT ABOUT A LAMP?',
#    'start': 258.124,
#    'duration': 2.136},
#   {'text': 'WOULD YOU TAKE A LAMP?', 'start': 260.26, 'duration': 1.167},
#   {'text': "THAT'S ON THE SET.", 'start': 261.427, 'duration': 0.601},
#   {'text': '>> THEY STARTED TO NAIL THOSE\nDOWN.',
#    'start': 262.028,
#    'duration': 2.436},
#   {'text': 'THROWS USUALLY -- THOSE ARE\nUSUALLY ADHERED TO THE SIDE',
#    'start': 264.464,
#    'duration': 1.968},
#   {'text': 'TABLE.', 'start': 266.432, 'duration': 0.201},
#   {'text': ">> James: YOU'VE EVEN TRIED?",
#    'start': 266.633,
#    'duration': 2.035},
#   {'text': 'DAMN IT.', 'start': 268.668, 'duration': 1.001}],
#  [{'text': '>> James: YOU NEVER MEET\nANYONE, YOU NEVER MEET ANYONE',
#    'start': 1.067,
#    'duration': 0.834},
#   {'text': 'THAT GOES OH, JACK McBRAYER,\nNEVER ONCE.',
#    'start': 1.935,
#    'duration': 3.203},
#   {'text': '>> SO MUCH SO YOU POP UP IN THE\nMOST UNEXPECTED PLACES, CUZ I',
#    'start': 5.171,
#    'duration': 5.739},
#   {'text': 'WAS SO SURPRISED WHEN I SAW THE\nPHOTOS FROM NICK JONAS AND PRI',
#    'start': 10.943,
#    'duration': 5.272},
#   {'text': "ANKE CHOPRA'S WEEK-LONG WEDDING,\nAND SEE ALL THESE PHOTOS AND YOU",
#    'start': 16.248,
#    'duration': 4.639},
#   {'text': 'WERE THERE.', 'start': 20.92, 'duration': 0.634},
#   {'text': "IT'S LIKE, HOW ARE YOU THERE?",
#    'start': 21.588,
#    'duration': 4.571},
#   {'text': 'HOW DID IT KM ABOUT THAT YOU\nENDED UP AT THAT WEDDING?',
#    'start': 26.192,
#    'duration': 3.27},
#   {'text': ">> I DON'T KNOW, I MET THE JONAS\nBROTHERS WAY BACK WHEN.",
#    'start': 29.495,
#    'duration': 2.503},
#   {'text': 'THEY WERE THE MUSICAL GUEST AT\nSATURDAY FIGHT LIFE, GOSH, IN',
#    'start': 32.031,
#    'duration': 5.205},
#   {'text': '200 THE.', 'start': 37.269, 'duration': 1.168},
#   {'text': 'AND WE JUST STAYED IN TOUCH AND\nOUR PATHS HAD CROSSED SINCE',
#    'start': 38.47,
#    'duration': 2.503},
#   {'text': 'THEN.', 'start': 41.006, 'duration': 1.135},
#   {'text': "AND NEXT THING YOU KNOW I'M\nFLYING TO INDIA FOR A WEDDING.",
#    'start': 42.174,
#    'duration': 4.438},
#   {'text': '>> James: HAD YOU BEEN BEFORE\nTO INIA, HAD YOU BEEN?',
#    'start': 46.645,
#    'duration': 3.438},
#   {'text': ">> NO, I'M NOT A VERY WELL\nTRAVELED INDIVIDUAL.",
#    'start': 50.116,
#    'duration': 3.537},
#   {'text': "I'VE BEEN TO CANADA.", 'start': 53.686, 'duration': 1.101},
#   {'text': "I'VE BEEN TO ENGLAND.", 'start': 54.82, 'duration': 1.702},
#   {'text': "I'VE BEEN TO INDIA.", 'start': 56.555, 'duration': 2.303},
#   {'text': "AND I'VE BEEN TO THE NORTH POLE\nWITH ALEXANDRA SKARSGARD.",
#    'start': 58.891,
#    'duration': 5.105},
#   {'text': '>> James: TELL US ABOUT THE\nWEDDING, WHAT WAS THE BEST PART',
#    'start': 64.029,
#    'duration': 3.638},
#   {'text': 'ABOUT IT.', 'start': 67.7, 'duration': 0.834},
#   {'text': ">> I DON'T KNOW WHAT THE WORSE\nPART WAS.",
#    'start': 68.568,
#    'duration': 2.869},
#   {'text': '>> James: NO, THE BEST PART.', 'start': 71.47, 'duration': 2.37},
#   {'text': '>> SIR.', 'start': 73.873, 'duration': 0.901},
#   {'text': '>> James: I THOUGHT YOU SAID\nTHE WORST PART.',
#    'start': 74.808,
#    'duration': 1.734},
#   {'text': '>> WHY WOULD I SAY THAT, I WAS\nTELLING YOU ABOUT A WEDDING IN',
#    'start': 76.575,
#    'duration': 3.771},
#   {'text': 'INDIA.', 'start': 80.379, 'duration': 0.868},
#   {'text': 'IT LASTS A WEEK LONG, WE WERE IN\nA PALACE.',
#    'start': 81.28,
#    'duration': 3.204},
#   {'text': 'A PALACE.', 'start': 84.517, 'duration': 1.802},
#   {'text': 'IT IS ONE OF THOSE THINGS WHERE\nYOU GET DRESS SHALL AFTER EVERY',
#    'start': 86.352,
#    'duration': 7.074},
#   {'text': 'DAVE THE WEDDING YOU COME BACK\nTO IT THE HOTEL ROOM THERE IS',
#    'start': 93.459,
#    'duration': 3.003},
#   {'text': 'SOMETHING NEW ON YOUR BED LIKE A\nPICTURE-- PICK STEUR FRAME OR',
#    'start': 96.495,
#    'duration': 6.04},
#   {'text': 'FANCY SCARF, OR THE-- ON THE\nLAST DAY THE GIFT IS A PIECE OF',
#    'start': 102.568,
#    'duration': 1.502},
#   {'text': 'LUGGAGE TO TAKE THE GIFTS HOME.',
#    'start': 104.103,
#    'duration': 2.97},
#   {'text': '>> James: THAT IS VERY SMART.',
#    'start': 107.106,
#    'duration': 1.735},
#   {'text': '>> THAT IS HOSTING.', 'start': 108.874, 'duration': 0.801},
#   {'text': '>> THAT IS CLASSY.', 'start': 109.708, 'duration': 1.536},
#   {'text': '>> James: ALEX AND RA, HAVE\nYOU EVER DONE A FANCY WEDDING',
#    'start': 111.277,
#    'duration': 3.804},
#   {'text': 'LIKE THAT.', 'start': 115.114, 'duration': 1.268},
#   {'text': ">> ACTUALLY, I WENT TO SOPHIE\nAND JO'S WEDDING.",
#    'start': 116.415,
#    'duration': 3.471},
#   {'text': '>> SHUT UP.', 'start': 119.919, 'duration': 0.401},
#   {'text': '>> IS THAT TRUE.', 'start': 120.353, 'duration': 2.736},
#   {'text': '>> MY INVITATION GOT LOST THEN.',
#    'start': 123.122,
#    'duration': 1.201},
#   {'text': ">> James: I DIDN'T GET INVITED\nTO EITHER WEDDING.",
#    'start': 124.356,
#    'duration': 2.937},
#   {'text': 'AND THIS MUST HAVE BEEN\nESPECIALLY GREAT FOR YOU',
#    'start': 127.326,
#    'duration': 3.571},
#   {'text': 'ALEXANDRA BECAUSE I KNOW YOU\nLIKE I ARE A BIG BOY BAND',
#    'start': 130.93,
#    'duration': 4.104},
#   {'text': 'FANATIC.', 'start': 135.067, 'duration': 1.235},
#   {'text': 'YOU SENT US THIS PHOTO HERE OF A\nYOUNG ALEXANDRA ON HER WAY TO A',
#    'start': 136.335,
#    'duration': 3.17},
#   {'text': 'CONCERT.', 'start': 139.538, 'duration': 0.768},
#   {'text': 'WHAT CONCERT WERE YOU GOING TO\nHERE.',
#    'start': 140.339,
#    'duration': 3.204},
#   {'text': '>> OKAY, SO I AM ON MY WAY TO\nTHIS CONCERT WHICH IS LIKE',
#    'start': 143.576,
#    'duration': 6.306},
#   {'text': 'A-- CONCERT WHERE IT WAS 98\nDEGREES, JUSTIN-- JUST TIN',
#    'start': 149.915,
#    'duration': 6.641},
#   {'text': 'TIMBER BAKE, CHRISTINA AGUILERA.',
#    'start': 156.589,
#    'duration': 1.535},
#   {'text': '>> James: THE TOP OF THE POP\nPARADE.',
#    'start': 158.157,
#    'duration': 0.968},
#   {'text': '>> EXACTLY.', 'start': 159.158, 'duration': 0.768},
#   {'text': 'AND I WAS READY, OKAY, AT THAT\nTIME.',
#    'start': 159.959,
#    'duration': 1.301},
#   {'text': 'I KEPT THAT SOAKER ON FOR ALMOST\nTHREE YEARS STRAIGHT.',
#    'start': 161.293,
#    'duration': 7.208},
#   {'text': "I'M SURE AT THIS POINT IT IS\nMOLDED TO MY NECK BECAUSE IT IS",
#    'start': 168.534,
#    'duration': 3.604},
#   {'text': 'CALLED FASHION.', 'start': 172.171, 'duration': 1.201},
#   {'text': 'AND THEN LIKE LATE 90S, EARLY 2\nTHOUSAND THEY HAD THOSE LITTLE',
#    'start': 173.406,
#    'duration': 4.237},
#   {'text': 'JEWELS YOU PUT IN YOUR HAIR AND\nTHEY ARE COMING BACK WHICH MAKES',
#    'start': 177.676,
#    'duration': 4.205},
#   {'text': 'ME EXCITEDMENT BUT IF ANYONE\nASKS I STARTED THAT TREND SWRZ',
#    'start': 181.914,
#    'duration': 2.803},
#   {'text': 'THAT WAS ALL YOU GOING TO SEE 98\nDEGREES.',
#    'start': 184.75,
#    'duration': 3.537},
#   {'text': '>> AND THEN LIKE A COUSIN TWICE\nREMOVED WAS ONE OF THEIR',
#    'start': 188.32,
#    'duration': 3.771},
#   {'text': 'ROADIES, SO WE GOT TO GO\nBACKSTAGE.',
#    'start': 192.124,
#    'duration': 1.802},
#   {'text': ">> James: NO, YOU DIDN'T.", 'start': 193.959, 'duration': 2.803},
#   {'text': '>> I MET NICK LASHEA.', 'start': 196.795, 'duration': 3.204},
#   {'text': 'I LOST MY COOKIES, I WAS SO\nSWEATIE LIKE I AM NOW.',
#    'start': 200.032,
#    'duration': 3.17},
#   {'text': 'AND I WAS JUST SO OBSESSED.', 'start': 203.235, 'duration': 2.603},
#   {'text': 'AND I WAS LIKE OH-- LIKE I WAS\nSPEAKING IN TONGUE, LIKE FAN',
#    'start': 205.871,
#    'duration': 6.273},
#   {'text': 'GIRL TONGUE OVER 98 DEGREES.',
#    'start': 212.177,
#    'duration': 1.369},
#   {'text': 'AND THEY ARE LIKE WHO IS THIS\nSMALL INFANTILE CHILD HAVING A',
#    'start': 213.579,
#    'duration': 6.607},
#   {'text': 'WHOLE MOMENT ON THE GROUND.', 'start': 220.219, 'duration': 2.403},
#   {'text': 'AND I NEEDED TO BE EXORCISED.',
#    'start': 222.655,
#    'duration': 1.702},
#   {'text': '>> James: SEE, I ALWAYS KNEW\nWE WOULD GET ON.',
#    'start': 224.39,
#    'duration': 1.969},
#   {'text': 'I ALWAYS KNEW WE WOULD GET ON.',
#    'start': 226.392,
#    'duration': 1.335}],
#  [{'text': ">> JAMES: WELCOME BACK, I'M\nHERE",
#    'start': 0.734,
#    'duration': 1.167},
#   {'text': 'AT THE BAR WITH MICHELLE\nZAUNER FROM JAPANESE\nBREAKFAST.',
#    'start': 1.935,
#    'duration': 4.437},
#   {'text': "( CHEERS AND APPLAUSE )\nI'M SO THRILLED YOU'RE HERE.",
#    'start': 6.405,
#    'duration': 1.902},
#   {'text': '>> THANK YOU.\n>> James: THANK YOU SO MUCH',
#    'start': 8.34,
#    'duration': 0.868},
#   {'text': 'FOR FINDING THE TIME TO BE\nON THE SHOW.',
#    'start': 9.241,
#    'duration': 7.008},
#   {'text': 'YOU HAVE BEEN NOMINATED FOR\nTWO GRAMMY AWARDS.',
#    'start': 16.282,
#    'duration': 1.769},
#   {'text': 'BEST NEW ARTIST BEST\nALTERNATIVE ALBUM NOW.',
#    'start': 18.084,
#    'duration': 3.47},
#   {'text': 'WHAT DID YOU DO AND WHERE\nWERE YOU WHEN YOU FOUND OUT\nABOUT THE',
#    'start': 21.587,
#    'duration': 2.97},
#   {'text': 'NOMINATIONS?\n>> I WAS IN MY APARTMENT IN',
#    'start': 24.59,
#    'duration': 1.802},
#   {'text': 'BROOKLYN AND I SCREAMED A\nLOT AND RAN AROUND AND MY\nNEIGHBORS',
#    'start': 26.425,
#    'duration': 4.705},
#   {'text': 'PROBABLY THOUGHT I WAS A\nCRAZY PERSON.',
#    'start': 31.163,
#    'duration': 2.336},
#   {'text': '>> James: AND WERE YOU ON\nYOUR OWN?',
#    'start': 33.532,
#    'duration': 1.435},
#   {'text': '>> I WAS WITH MY HUSBAND.\nI THINK MY MANAGER MIGHT\nHAVE',
#    'start': 35.0,
#    'duration': 6.507},
#   {'text': 'KNOWN BEFOREHAND AND SAID\nYOU SHOULD FILM HER\nREACTION.',
#    'start': 41.54,
#    'duration': 3.204},
#   {'text': "SO MY HUSBAND WASN'T THE\nMOST SAVVY PERSON.",
#    'start': 44.777,
#    'duration': 3.37},
#   {'text': 'HE MOSTLY FILMED THE TV WHEN\nTHE ANNOUNCEMENT CAME, AND\nFLASHED',
#    'start': 48.18,
#    'duration': 3.771},
#   {'text': 'TO ME TO GET MY REACTION AND\nWANTED TO MAKE SURE TO GET\nTHE',
#    'start': 51.984,
#    'duration': 4.705},
#   {'text': "TV.\n>> James: YOU'RE THE STORY",
#    'start': 56.722,
#    'duration': 0.901},
#   {'text': 'HERE.\nLOTS OF PEOPLE CAN SEE IT ON\nTV,',
#    'start': 57.656,
#    'duration': 3.871},
#   {'text': "YOU'RE IN THE ROOM WITH THE\nNOMINEE.",
#    'start': 61.56,
#    'duration': 2.67},
#   {'text': '>> YES.\n>> James: THIS, I THINK, IS\nAS',
#    'start': 64.263,
#    'duration': 1.836},
#   {'text': 'COOL AS THE GRAMMY\nNOMINATION, YOU HAVE BEEN\nHONORED IN YOUR',
#    'start': 66.132,
#    'duration': 3.971},
#   {'text': 'HOMETOWN OF PHILLY.\nTELL EVERYBODY WHAT HAPPENED\nTO',
#    'start': 70.136,
#    'duration': 2.569},
#   {'text': 'YOU THERE.\n>> YEAH, SO I USED TO WORK\nAT A',
#    'start': 72.738,
#    'duration': 2.903},
#   {'text': 'VENUE CALLED UNION TRANSFER\nAT THE COAT CHECK, AND I\nRECENTLY',
#    'start': 75.674,
#    'duration': 5.139},
#   {'text': 'SOLD OUT FIVE NIGHTS AT\nUNION TRANSFER.',
#    'start': 80.846,
#    'duration': 3.104},
#   {'text': '>> James: OF COURSE YOU DID.\nTHAT MUST BE AN AMAZING\nTHEATER.',
#    'start': 83.983,
#    'duration': 2.836},
#   {'text': "THAT'S UNBELIEVABLE!\n( APPLAUSE )",
#    'start': 86.852,
#    'duration': 4.472},
#   {'text': '>> WHILE I WAS WORKING AT\nTHE CO-CHECK I TOOK A FAKE\n$100 BILL',
#    'start': 91.357,
#    'duration': 7.241},
#   {'text': 'AND GAVE SOMEONE $99 IN\nCHANGE. AND SEAN STEPPED UP\nAND SAID',
#    'start': 98.631,
#    'duration': 6.94},
#   {'text': "I'LL TAKE CARE OF IT.\nON THE LAST NIGHT OF THE\nSHOWS,",
#    'start': 105.604,
#    'duration': 3.07},
#   {'text': 'I SAID, SEAN, COME UP, I\nHAVE $100 FOR YOU, I CAN\nAFFORD TO',
#    'start': 108.707,
#    'duration': 4.138},
#   {'text': 'PAY IT BACK NOW.\nAT THE END OF THE SHOW, THEY',
#    'start': 112.878,
#    'duration': 2.436},
#   {'text': "TOOK ME OUT AND HAND PAINTED\nMICHELLE ZAUNER'S COAT\nCHECK.",
#    'start': 115.347,
#    'duration': 6.541},
#   {'text': 'ON THE PLAQUE, THEY SAY MAY\nEVERYONE WHO WORKS HERE GO\nON TO',
#    'start': 121.921,
#    'duration': 3.67},
#   {'text': 'SELL OUT FIVE NIGHT AT COAT\nTRANSFER.',
#    'start': 125.624,
#    'duration': 3.337},
#   {'text': '>> James: OH, MY GOD I LOVE\nSEAN!',
#    'start': 128.994,
#    'duration': 2.403},
#   {'text': "THAT'S AMAZING, INCREDIBLE!\nIT'S ANNOUNCED YOU WILL PLAY",
#    'start': 131.43,
#    'duration': 5.372},
#   {'text': 'COACHELLA THIS YEAR.\nTHERE ARE SO MANY BRILLIANT',
#    'start': 136.835,
#    'duration': 4.272},
#   {'text': "ARTISTS.\nWHEN YOU KNOW YOU'RE IN A",
#    'start': 141.14,
#    'duration': 3.804},
#   {'text': 'LINEUP, DO YOU PLAY AND\nLEAVE OR STICK AROUND AND\nSEE THEM.',
#    'start': 144.977,
#    'duration': 7.241},
#   {'text': '>> WE PLAYED BAYCHELLA AND\nWATCHED BEYONCE.',
#    'start': 152.251,
#    'duration': 9.043},
#   {'text': "BUT I'M LOOKING FORWARD TO\nTHE EXCELLENT CATERING AT\nCOACHELLA.",
#    'start': 161.327,
#    'duration': 5.539},
#   {'text': ">> James: REALLY?\nYEAH, IT'S ONE TO HAVE THE",
#    'start': 166.899,
#    'duration': 2.803},
#   {'text': 'FIRST FESTIVALS WE PLAYED\nAND THEY HAVE EIGHT\nDIFFERENT TYPES',
#    'start': 169.735,
#    'duration': 3.337},
#   {'text': "OF SPA WATER.\nSO I'M VERY LOOKING FORWARD\nTO",
#    'start': 173.105,
#    'duration': 3.237},
#   {'text': "THE CATERING.\n>> James: THAT'S GOT TO BE\nBAD",
#    'start': 176.375,
#    'duration': 1.969},
#   {'text': "IF THAT'S THE FIRST ONE YOU\nPLAY.",
#    'start': 178.377,
#    'duration': 2.436},
#   {'text': '>> YEAH.\n>> James: SO YOU JUST',
#    'start': 180.846,
#    'duration': 2.103},
#   {'text': 'ASSUME --\n>> EVERYTHING ELSE IS\nDOWNHILL.',
#    'start': 182.982,
#    'duration': 1.668},
#   {'text': '>> James: YOU ASSUME ALL\nFESTIVALS HAVE AMAZING.',
#    'start': 184.683,
#    'duration': 4.539},
#   {'text': ">> THERE'S NO SPA WATER\nANYWHERE ELSE BUT EIGHT\nKINDS AT",
#    'start': 189.255,
#    'duration': 1.768},
#   {'text': "COACHELLA.\n>> James: WE'RE SO HAPPY FOR YOU",
#    'start': 191.056,
#    'duration': 6.474},
#   {'text': 'JAPANESE BREAKFAST WILL\nPERFORM WHEN WE COME BACK.',
#    'start': 197.563,
#    'duration': 3.404}],
#  [{'text': '♪\n>> James: HI, HOW ARE YOU?', 'start': 1.267, 'duration': 2.836},
#   {'text': 'THANK YOU FOR BEING HERE.', 'start': 4.136, 'duration': 2.169},
#   {'text': "I WANT TO START BY SAYING WE'VE\nPLAYED THAT CELL PHONE PROFILE",
#    'start': 6.338,
#    'duration': 2.67},
#   {'text': 'GAME LIKE TWO OR THREE TIMES.', 'start': 9.041, 'duration': 2.37},
#   {'text': "YOU ARE WITHOUT QUESTION THE\nBEST PERSON THAT'S EVER PLAYED",
#    'start': 11.444,
#    'duration': 4.471},
#   {'text': 'THAT, IN TERMS OF KNOCKING ME\nOFF THE SCENT.',
#    'start': 15.948,
#    'duration': 3.204},
#   {'text': ">> WHICH IS WEIRD BECAUSE I'M A\nTERRIBLE LIAR.",
#    'start': 19.185,
#    'duration': 2.069},
#   {'text': "I AM A GOOD ACTOR BUT I'M A BAD\nLIAR SO I AM SHOCKED THAT I",
#    'start': 21.287,
#    'duration': 4.338},
#   {'text': 'ACTUALLY DID THAT.', 'start': 25.658, 'duration': 1.035},
#   {'text': '>> James: BUT EVEN SAYING THAT\nFEELS LIKE A LIE NOW.',
#    'start': 26.726,
#    'duration': 1.802},
#   {'text': "I DON'T TRUST ANYTHING YOU SAY.",
#    'start': 28.561,
#    'duration': 1.969},
#   {'text': '>> RUINED IT.', 'start': 30.563, 'duration': 0.901},
#   {'text': '>> THAT WAS\nEXTRAORDINARILY-- THEY WERE BOTH',
#    'start': 31.498,
#    'duration': 2.635},
#   {'text': 'GREAT.', 'start': 34.166, 'duration': 0.601},
#   {'text': 'I WAS DEFINITIVELY TERRIBLE.', 'start': 34.8, 'duration': 1.902},
#   {'text': '>> James: REALLY, YOU\nTHOUGHT.',
#    'start': 36.735,
#    'duration': 2.07},
#   {'text': '>> MY SUBWAY LIZZO SONG WAS\nSUCH.',
#    'start': 38.838,
#    'duration': 4.238},
#   {'text': '>> I LIKE IT.', 'start': 43.109, 'duration': 1.868},
#   {'text': '>> CRAP.', 'start': 45.01, 'duration': 1.101},
#   {'text': '>> James: I FEEL LIKE LIZZO IS\nSITTING-- SITTING AT HOME',
#    'start': 46.145,
#    'duration': 3.17},
#   {'text': 'THINKING THAT IS WHAT THE SNG\nCOULD HAVE BEEN AM NOW MELISSA,',
#    'start': 49.348,
#    'duration': 2.803},
#   {'text': 'WE HAVE TO CONGRATULATE YOU.', 'start': 52.184, 'duration': 1.335},
#   {'text': 'YOU GOT MARRIED JUST A MATTER OF\nWEEKS AGO.',
#    'start': 53.552,
#    'duration': 2.937},
#   {'text': '>> I DID.', 'start': 56.522, 'duration': 0.601},
#   {'text': '>> James: HERE YOU ARE HERE.', 'start': 57.156, 'duration': 1.602},
#   {'text': 'THIS HANDSOME MAN.', 'start': 58.791, 'duration': 2.069},
#   {'text': 'HOW IS IT, HOW IS MARRIED LIFE\nTREATING YOU SO FAR?',
#    'start': 60.893,
#    'duration': 4.138},
#   {'text': ">> IT'S GREAT.", 'start': 65.064, 'duration': 1.068},
#   {'text': 'WE HAD A REALLY, REALLY NICE\nDAY, IT WAS VERY SPECIAL.',
#    'start': 66.165,
#    'duration': 4.438},
#   {'text': '>> WHAT WAS THE HIGHLIGHT?', 'start': 70.636, 'duration': 2.136},
#   {'text': '>> OF THE DAY?', 'start': 72.805, 'duration': 1.168},
#   {'text': '>> James: YES.', 'start': 74.006, 'duration': 0.601},
#   {'text': ">> I DON'T REMEMBER.", 'start': 74.64, 'duration': 1.135},
#   {'text': "THEY DON'T LIE WHEN THEY TELL\nYOU LIKE IT GUESS LIKE THAT.",
#    'start': 75.808,
#    'duration': 3.037},
#   {'text': '>> James: MY WEDDING FELT LIKE\nIT LASTED A YEAR.',
#    'start': 78.878,
#    'duration': 3.804},
#   {'text': '(LAUGHTER)\nI FELT LIKE I LOOKED AT THE',
#    'start': 82.715,
#    'duration': 1.802},
#   {'text': 'CLOCK AND I THOUGHT WE SHOULD\nPROBABLY BE HEADING TO BED, IT',
#    'start': 84.55,
#    'duration': 2.77},
#   {'text': 'WAS LIKE 8:30.', 'start': 87.353, 'duration': 1.268},
#   {'text': 'BUT THIS WILL BE YOUR FIRST\nTHANKS GIVING AS A PARIED',
#    'start': 88.654,
#    'duration': 3.504},
#   {'text': 'COUPLE.', 'start': 92.191, 'duration': 0.834},
#   {'text': '>> YES.', 'start': 93.058, 'duration': 0.935},
#   {'text': '>> James: HOW WILL YOU BE\nSPENDING YOUR FIRST',
#    'start': 94.026,
#    'duration': 1.902},
#   {'text': 'THANKSGIVING.', 'start': 95.961, 'duration': 1.201},
#   {'text': ">> WE'RE HOSTING FOR THE FIRST\nTIME, AGAIN HUGE MISTAKE, CARRY",
#    'start': 97.196,
#    'duration': 2.002},
#   {'text': 'ON.', 'start': 99.231, 'duration': 0.968},
#   {'text': ">> I'M REALIZING THAT VERY\nQUICKLY.",
#    'start': 100.232,
#    'duration': 1.435},
#   {'text': 'MY HUSBAND DID ALL THIS RESEARCH\nAND HE GOT A HERITAGE TURKEY',
#    'start': 101.7,
#    'duration': 2.67},
#   {'text': 'WHICH I DONE KNOW WHAT THAT IS.',
#    'start': 104.403,
#    'duration': 1.669},
#   {'text': 'AND IT TOOK HIM LIKE SIX HOURS\nAND APPARENTLY IT IS THE CLOSEST',
#    'start': 106.105,
#    'duration': 5.639},
#   {'text': 'GENETICALLY TO WHAT THE PILL\nGRILL-- PILGRIMS AND NATIVE',
#    'start': 111.777,
#    'duration': 3.637},
#   {'text': 'AMERICANS ATE.', 'start': 115.447, 'duration': 1.168},
#   {'text': "I'M LIKE WHAT IS GOING TO COME\nTO MY HOUSE SWRZ THAT IS WHAT",
#    'start': 116.648,
#    'duration': 2.07},
#   {'text': 'YOU LOOK FOR IN THE PACKAGE.',
#    'start': 118.751,
#    'duration': 1.201},
#   {'text': 'THAT IS WHAT I AM LOOKING FOR\nWHAT DID THE PILGRIMS EAT, THAT',
#    'start': 119.986,
#    'duration': 3.236},
#   {'text': 'SHOULD DO ME, YEAH.', 'start': 123.255, 'duration': 2.136},
#   {'text': '>> THE CLOSEST GENETICALLY, CAN\nYOU EXPLAIN THAT MORE.',
#    'start': 125.424,
#    'duration': 2.97},
#   {'text': ">> I DON'T KNOW, IT COULD BE A\nMONSTER.",
#    'start': 128.427,
#    'duration': 1.902},
#   {'text': "WE'LL SEE.", 'start': 130.362, 'duration': 1.068},
#   {'text': '>> James: YOUR FONDEST\nMEMORIES OF THANKS GIVING, MIKE.',
#    'start': 131.463,
#    'duration': 4.605},
#   {'text': ">> WHEN IS WITH A KID WE USED TO\nGO TO MY BROTHER'S GODFATHER'S",
#    'start': 136.101,
#    'duration': 3.838},
#   {'text': "MOTHER AND FATHER'S HOUSE AND\nPUT ON THIS EXTRAVAGANT",
#    'start': 139.972,
#    'duration': 4.471},
#   {'text': 'THANKSGIVING EVERY YEAR.', 'start': 144.476, 'duration': 1.101},
#   {'text': 'I WAS A VERY PICKY EATER AND ALL\nI WOULD EAT WAS A ROLL.',
#    'start': 145.611,
#    'duration': 4.471},
#   {'text': 'AND I WOULD BE MOCKED FOR IT AND\nI WOULD EAT ABOUT 15, 16 ROLLS.',
#    'start': 150.115,
#    'duration': 4.272},
#   {'text': 'AND THEN I WOULD GET SICK AND I\nWOULD FALL ASLEEP ON THE COUCH',
#    'start': 154.42,
#    'duration': 4.671},
#   {'text': 'WATCHING HBO.', 'start': 159.124, 'duration': 1.135},
#   {'text': 'BECAUSE THEY HAD HBO.', 'start': 160.292, 'duration': 1.135},
#   {'text': 'AND SO I WOULD WATCH LIKE EDDIE\nMURPHY SPECIALS AND STUFF.',
#    'start': 161.46,
#    'duration': 2.903},
#   {'text': '>> James: OH YEAH.', 'start': 164.396, 'duration': 1.002},
#   {'text': '>> HOW OLD WERE YOU.', 'start': 165.431, 'duration': 1.168},
#   {'text': '>> I WAS LIKE A KID, TEN, 11, I\nWOULD FORGET ABOUT IT, NEXT',
#    'start': 166.632,
#    'duration': 1.902},
#   {'text': 'YEAR, 16 ROLLS AN AN EDDIE\nMURPHY SPECIAL, THAT IS PRETTY',
#    'start': 168.567,
#    'duration': 3.904},
#   {'text': 'MUCH MY THANKSGIVING EVERY YEAR.',
#    'start': 172.504,
#    'duration': 1.302},
#   {'text': '>> James: WILL IT BE THE SAME\nTHIS YEAR.',
#    'start': 173.839,
#    'duration': 2.169},
#   {'text': '>> YEAH, WE ARE HEADING OVER\nTHERE.',
#    'start': 176.041,
#    'duration': 0.801},
#   {'text': 'THEY HAVE HBO.', 'start': 176.875, 'duration': 1.035},
#   {'text': 'NO, KIDDING.', 'start': 177.943, 'duration': 1.035},
#   {'text': '>> THAT IS THE CLOSEST\nTHANKSGIVING THAT THE PILGRIMS',
#    'start': 179.011,
#    'duration': 2.303},
#   {'text': 'HAD.', 'start': 181.347, 'duration': 0.567},
#   {'text': '>> THAT IS WHAT THEY HAD.', 'start': 181.948, 'duration': 1.301},
#   {'text': 'GENETICALLY.', 'start': 183.282, 'duration': 0.801},
#   {'text': '>> James: THAT HERITAGE\nTHANKSGIVING.',
#    'start': 184.116,
#    'duration': 1.235},
#   {'text': '>> EXACTLY CORRECT.', 'start': 185.384, 'duration': 1.235},
#   {'text': '>> IF YOU WANT TO TRACE IT\nGENETICALLY, THAT IS HOW IT IS.',
#    'start': 186.652,
#    'duration': 2.003}]]
